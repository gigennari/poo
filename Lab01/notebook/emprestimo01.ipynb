// %% [markdown]
// # Exercício do Empréstimo
//
// Em um financiamento com juros compostos e número de parcelas fixas parte-se dos seguintes parâmetros:
// * `S` - valor da primeira parcela
// * `N` - número de parcelas
// * `J` - percentual de juros mensal
//
// A primeira parcela a ser paga do financiamento é sempre igual a `S`. A partir daí é feita uma atualização mensal da parcela, em que cada nova parcela é calculada a partir da parcela do mês anterior, conforme a fórmula:
//
// > #### Parcela<sub>mês</sub> = Parcela<sub>mês-1</sub> * (1 + `J` / 100)
//
// O financiamento encerra quando as `N` parcelas são pagas.
//
// Exemplo:
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// Parcelas do financiamento:
// `200`; `202`; `204.02`; `206.06`; `208.12`

// %% [markdown]
// ## Exercício Parte 1 - Escrevendo um Módulo
//
// Dado o problema descrito, escreva um programa que calcule as parcelas de um empréstimo para os seguintes valores:
// * `S`: 200
// * `N`: 5
// * `J`: 1%

// %%
#include <stdio.h>

int main(){

    //parcela incial 
    float S = 200;    
    //numero de parcelas 
    int N = 5;
    //juros mensais em %
    float J = 0.01;

    printf("As parcelas do financiamento:\n");

    
    for (int i = 1; i <= N; i++){
        printf("%.2f; ", S);
        float S_novo = S * (1 + J);;
        printf("%.2f; ", S_novo);
        S = S_novo;
    }
    printf("\n");
}
// Out:
// As parcelas do financiamento:
// 200.00; 202.00; 202.00; 204.02; 204.02; 206.06; 206.06; 208.12; 208.12; 210.20;

// %% [markdown]
// ## Exercício Parte 2 - Escrevendo um Módulo (Função)
//
// Reescreva o código acima de forma que seu programa faça uso de uma função `proximaParcela` que seja responsável pelo cálculo de uma única parcela X do empréstimo. Utilize as boas práticas de modularização que você aprendeu, evitando dependências do módulo com o programa principal. A função deve apenas calcular uma única parcela, portanto, ficará a cargo da função principal que chama `proximaParcela` realizar o restante do processo, para que sejam apresentadas todas as parcelas do financiamento.

// %%
#include <stdio.h>
#include <math.h>

float nova_parcela(int *i, int n, float s, float j, float *p){
    if(*i == 0){
        *p = s;
    }
    else if (*i <= n){
        *p = *p * (1 + j);
    }
    else{
        *p = 0;
    }
    (*i)++;
    
    return *p;

}

int main(){

    //parcela incial 
    float s = 200;    
    //numero de parcelas 
    int n = 5;
    //juros mensais em %
    float j = 0.01;

    int atual = 0;
    float p = s;

    printf("As parcelas do financiamento:\n");
    for (int i = 0; i < n; i++){
        p = nova_parcela(&atual, n, s, j, &p);
        
        printf("%.2f; ", p);
    }   
    return 0;
}
// Out:
// As parcelas do financiamento:
// 200.00; 202.00; 204.02; 206.06; 208.12;

// %% [markdown]
// ## Exercício Parte 3 - Mantendo o Estado
//
// Modifique a função (módulo) `proximaParcela` acima de modo que ela tenha uma memória da situação em que estão as coisas, sem que o `main` precise ficar informando novamente coisas que já informou no início. Para isso serão permitidas as seguintes modificações:
//
// 1. você pode desmembrar a função em mais de uma, por exemplo, uma você chama no começo do empréstimo e outra a cada parcela;
//
// 2. você pode usar técnicas de uso de variáveis não recomendadas que geram dependência dos módulos com o programa principal.
//
// Você deve organizar o código de tal maneira que o `main` informe para as funções os dados do financiamento apenas uma única vez e depois possa solicitar o cálculo da parcela subsequente sem informar tudo novamente.

// %%
#include <stdio.h>
#include <math.h> 

float nova_parcela(float p_atual, float j, int i){
    p_atual = p_atual * (1 + j) ;
    return p_atual;

}

void calcular_parcelas(float s, float n, float j){
    printf("As parcelas do financiamento:\n");
    
    float p = s;
    printf("%.2f; ", p);
    for (int i = 1; i < n; i++){
        
        p = nova_parcela(p, j, i);
        printf("%.2f; ", p);
        
    }
    printf("\n");
}

int main(){

    //parcela incial 
    float S = 200;    
    //numero de parcelas 
    int N = 5;
    //juros mensais em %
    float J = 0.01;

    calcular_parcelas(S, N, J);

    return 0;
}
// Out:
// As parcelas do financiamento:
// 200.00; 202.00; 204.02; 206.06; 208.12;

// %% [markdown]
// ## Exercício Parte 4 - Minimizando os Parâmetros
//
// Partindo da Solução da Parte 2, modifique a forma como você representa o empréstimo, de forma que a função que calcula a próxima parcela receba um único parâmetro.

// %%
#include <stdio.h>

typedef struct{
    int n, i;
    float s, j, p_atual;

}Emprestimo;

Emprestimo proxima_parcela(Emprestimo e){
 
    e->p_atual = e->p_atual * (1 + e->j);
    return e;
}

void calcular_parcelas(Emprestimo e){
    printf("As parcelas do financiamento:\n");
    while(e->i < e->n){
        e = proxima_pacela(e);
        printf("%.2f", e->p_atual);
    }
}

int main(){
    Emprestimo emprestimo1;
    emprestimo1->n = 5;
    emprestimo1->s = 200;
    emprestimo->j = 0.01;
    
    calcular_parcelas(emprestimo1);
    return 0;
}
// Out:
// /tmp/tmpjglgwkx3.c: In function ‘proxima_parcela’:
// /tmp/tmpjglgwkx3.c:11:6: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//       ^~
// /tmp/tmpjglgwkx3.c:11:19: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//                    ^~
// /tmp/tmpjglgwkx3.c:11:37: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//                                      ^~
// /tmp/tmpjglgwkx3.c: In function ‘calcular_parcelas’:
// /tmp/tmpjglgwkx3.c:17:12: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      while(e->i < e->n){
//             ^~
// /tmp/tmpjglgwkx3.c:17:19: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      while(e->i < e->n){
//                    ^~
// /tmp/tmpjglgwkx3.c:18:13: warning: implicit declaration of function ‘proxima_pacela’; did you mean ‘proxima_parcela’? [-Wimplicit-function-declaration]
//          e = proxima_pacela(e);
//              ^~~~~~~~~~~~~~
//              proxima_parcela
// /tmp/tmpjglgwkx3.c:18:11: error: incompatible types when assigning to type ‘Emprestimo {aka struct <anonymous>}’ from type ‘int’
//          e = proxima_pacela(e);
//            ^
// /tmp/tmpjglgwkx3.c:19:25: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//          printf("%.2f", e->p_atual);
//                          ^~
// /tmp/tmpjglgwkx3.c: In function ‘main’:
// /tmp/tmpjglgwkx3.c:25:16: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      emprestimo1->n = 5;
//                 ^~
// /tmp/tmpjglgwkx3.c:26:16: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct <anonymous>}’)
//      emprestimo1->s = 200;
//                 ^~
// /tmp/tmpjglgwkx3.c:27:5: error: ‘emprestimo’ undeclared (first use in this function); did you mean ‘emprestimo1’?
//      emprestimo->j = 0.01;
//      ^~~~~~~~~~
//      emprestimo1
// /tmp/tmpjglgwkx3.c:27:5: note: each undeclared identifier is reported only once for each function it appears in
// [C kernel] GCC exited with code 1, the executable will not be executed

// %% [markdown]
// ## Exercício Parte 5 - Múltiplos Empréstimos
//
// Considere que há múltiplos empréstimos que podem ser controlados em paralelo. O seu programa deve ser capaz de informar as parcelas de mais de um empréstimo, mantendo um controle para cada empréstimo separadamente. Você deve decidir qual das soluções tomará como ponto de partida, se deve modificar o programa principal, a função ou ambos para atender esse requisito da melhor forma possível.
//
// Por exemplo, suponha os seguintes dois empréstimos em paralelo:
//
// ### Empréstimo 1
// * `S`: 200
// * `N`: 5
// * `J`: 1%
//
// ### Empréstimo 2
// * `S`: 500
// * `N`: 7
// * `J`: 2%
//
// A saída esperada é:
// ~~~
// Emprestimo 1: parcela 1 eh 200.00
// Emprestimo 2: parcela 1 eh 500.00
// Emprestimo 1: parcela 2 eh 202.00
// Emprestimo 2: parcela 2 eh 510.00
// Emprestimo 1: parcela 3 eh 204.02
// Emprestimo 2: parcela 3 eh 520.20
// Emprestimo 1: parcela 4 eh 206.06
// Emprestimo 2: parcela 4 eh 530.60
// Emprestimo 1: parcela 5 eh 208.12
// Emprestimo 2: parcela 5 eh 541.22
// Emprestimo 2: parcela 6 eh 552.04
// Emprestimo 2: parcela 7 eh 563.08
// ~~~
//
// O exemplo mostra dois empréstimos, mas a estrutura deve ser genérica o suficiente para controlar N empréstimos em paralelo.

// %%
/**
 * Guarda o registro inteiro 
 * */

typedef struct Emprestimo{
    int n, i;
    float s, j, p_atual;
    struct Emprestimo *prox;

}Emprestimo;

/**
 * Guarda o enedereço de um registro
 * */
typedef struct No *p_emp;

/**
 * Na primeira lista, p_no aponta para NULL 
 * */
p_emp criar_lista()
{
    return NULL;
}

/**
 * Adiciona elemento no começo das listas ligadas 
 * Então a primeira lista vira a segunda
 *  O(n)
 * */
p_emp adicionar_emprestimo(p_emp lista_antiga, p_emp emp_novo)
{

    if(lista_antiga != NULL){
       emp_novo->prox = lista_antiga; //a lista antiga é o próximo nó 
    }
    return emp_novo;
}

p_emp criar_emprestimo(int n, float s, float j){
    p_emp emp_novo = malloc(sizeof(Emprestimo));
    emp_novo->i = 0;
    emp_novo->n = n;
    emp->novo->s = s;
    emp_novo->j = j;
    emp_novo->p_atual = s;
    emp_novo->prox = NULL;
    return emp_novo;
}

float proxima_parcela(Emprestimo e){
 

    e->p_atual = e->p_atual * (1 + e->j);
    return e;
}

void calcular_parcelas(p_emp e){
    do{
        if(e->i =< e->n){
            e->p_atual = proxima_parcela(e);
            printf("%.2f", e->p_atual);
        }
                
    }while(e->prox != NULL);
}

int main(){
    p_emp lista_emprestimos = criar_lista();
    p_emp e1 = criar_emprestimo(5, 200, 0.01);
    p_emp e2 = criar_emprestimo

    lista_emprestimos = adicionar_emprestimo(e1);
    lista_emprestimos = adicionar_emprestimo(e2);

    calcular_parcelas(lista_emprestimos);


    
}
// Out:
// /tmp/tmpibddubrd.c: In function ‘criar_lista’:
// /tmp/tmpibddubrd.c:22:12: error: ‘NULL’ undeclared (first use in this function)
//      return NULL;
//             ^~~~
// /tmp/tmpibddubrd.c:22:12: note: each undeclared identifier is reported only once for each function it appears in
// /tmp/tmpibddubrd.c: In function ‘adicionar_emprestimo’:
// /tmp/tmpibddubrd.c:33:24: error: ‘NULL’ undeclared (first use in this function)
//      if(lista_antiga != NULL){
//                         ^~~~
// /tmp/tmpibddubrd.c:34:16: error: dereferencing pointer to incomplete type ‘struct No’
//         emp_novo->prox = lista_antiga; //a lista antiga é o próximo nó
//                 ^~
// /tmp/tmpibddubrd.c: In function ‘criar_emprestimo’:
// /tmp/tmpibddubrd.c:40:22: warning: implicit declaration of function ‘malloc’ [-Wimplicit-function-declaration]
//      p_emp emp_novo = malloc(sizeof(Emprestimo));
//                       ^~~~~~
// /tmp/tmpibddubrd.c:40:22: warning: incompatible implicit declaration of built-in function ‘malloc’
// /tmp/tmpibddubrd.c:40:22: note: include ‘<stdlib.h>’ or provide a declaration of ‘malloc’
// /tmp/tmpibddubrd.c:43:5: error: ‘emp’ undeclared (first use in this function); did you mean ‘p_emp’?
//      emp->novo->s = s;
//      ^~~
//      p_emp
// /tmp/tmpibddubrd.c:46:22: error: ‘NULL’ undeclared (first use in this function)
//      emp_novo->prox = NULL;
//                       ^~~~
// /tmp/tmpibddubrd.c: In function ‘proxima_parcela’:
// /tmp/tmpibddubrd.c:53:6: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct Emprestimo}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//       ^~
// /tmp/tmpibddubrd.c:53:19: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct Emprestimo}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//                    ^~
// /tmp/tmpibddubrd.c:53:37: error: invalid type argument of ‘->’ (have ‘Emprestimo {aka struct Emprestimo}’)
//      e->p_atual = e->p_atual * (1 + e->j);
//                                      ^~
// /tmp/tmpibddubrd.c:54:12: error: incompatible types when returning type ‘Emprestimo {aka struct Emprestimo}’ but ‘float’ was expected
//      return e;
//             ^
// /tmp/tmpibddubrd.c: In function ‘calcular_parcelas’:
// /tmp/tmpibddubrd.c:59:18: error: expected expression before ‘<’ token
//          if(e->i =< e->n){
//                   ^
// /tmp/tmpibddubrd.c:60:42: error: incompatible type for argument 1 of ‘proxima_parcela’
//              e->p_atual = proxima_parcela(e);
//                                           ^
// /tmp/tmpibddubrd.c:50:7: note: expected ‘Emprestimo {aka struct Emprestimo}’ but argument is of type ‘p_emp {aka struct No *}’
//  float proxima_parcela(Emprestimo e){
//        ^~~~~~~~~~~~~~~
// /tmp/tmpibddubrd.c:61:13: warning: implicit declaration of function ‘printf’ [-Wimplicit-function-declaration]
//              printf("%.2f", e->p_atual);
//              ^~~~~~
// /tmp/tmpibddubrd.c:61:13: warning: incompatible implicit declaration of built-in function ‘printf’
// /tmp/tmpibddubrd.c:61:13: note: include ‘<stdio.h>’ or provide a declaration of ‘printf’
// /tmp/tmpibddubrd.c:64:23: error: ‘NULL’ undeclared (first use in this function)
//      }while(e->prox != NULL);
//                        ^~~~
// /tmp/tmpibddubrd.c: In function ‘main’:
// /tmp/tmpibddubrd.c:70:16: warning: initialization from incompatible pointer type [-Wincompatible-pointer-types]
//      p_emp e2 = criar_emprestimo
//                 ^~~~~~~~~~~~~~~~
// /tmp/tmpibddubrd.c:72:5: error: expected ‘,’ or ‘;’ before ‘lista_emprestimos’
//      lista_emprestimos = adicionar_emprestimo(e1);
//      ^~~~~~~~~~~~~~~~~
// /tmp/tmpibddubrd.c:73:25: error: too few arguments to function ‘adicionar_emprestimo’
//      lista_emprestimos = adicionar_emprestimo(e2);
//                          ^~~~~~~~~~~~~~~~~~~~
// /tmp/tmpibddubrd.c:30:7: note: declared here
//  p_emp adicionar_emprestimo(p_emp lista_antiga, p_emp emp_novo)
//        ^~~~~~~~~~~~~~~~~~~~
// [C kernel] GCC exited with code 1, the executable will not be executed
